# %%
# Python
import pandas as pd
import numpy as np
from fbprophet import Prophet
# Data process
import pandas as pd
import numpy as np
# SARIMA Model
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.seasonal import seasonal_decompose

from sklearn.linear_model import LinearRegression, Lasso, Ridge,MultiTaskLassoCV
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import BaggingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
import plotly.plotly as py
import plotly.graph_objs as go
# Other
import datetime
import pickle
from plotly_utils.utils import get_plotly_fig

# %matplotlib inline
pylab.rcParams['figure.figsize'] = 25, 8

# %%
dataset = pd.read_pickle('../datasets/Full_Task2_Dataframe.pkl')
del dataset['EarlyPeakTrafficTime']
del dataset['LatePeakTrafficTime']
del dataset['NormalTrafficTime']

# %%
dataset["Hour"] = dataset.index.map(lambda dt:dt.hour)

# %%
dataset["Time"] = dataset.index.map(lambda dt:dt.time)

# %%
dataset.columns
# Out:
# Index(['T1D0', 'T1D1', 'T2D0', 'T3D0', 'T3D1', 'HeavyRain', 'LightRain',
#        'Rain', 'Sunny', 'DayOfWeek', 'BeforeNationalDay',
#        'NationalDayFront(1-4)', 'NationalDayTail(5-7)', 'Weekend',
#        'WorkingDay', 'WorkingWeekend', 'Hour', 'Time'],
#       dtype='object')

# %%
ax = sns.boxplot(x="Time", y="T1D1", data=dataset)

# %%
sns.boxplot(x="Time", y="T2D0", data=dataset)

# %%
sns.boxplot(x="Hour", y="T3D0", data=dataset)

# %%
sns.boxplot(x="Hour", y="T3D1", data=dataset)

# %%
sns.boxplot(x="WorkingDay", y="T2D0", data=dataset)

# %%
dataset
# Out:
#                      T1D0   T1D1   T2D0   T3D0   T3D1  HeavyRain  LightRain  \
# 2016-09-19 00:00:00  13.0    0.0    2.0   17.0    0.0        0.0        0.0
# 2016-09-19 00:20:00   6.0    0.0    0.0   16.0    0.0        0.0        0.0
# 2016-09-19 00:40:00   9.0    0.0    0.0   16.0    0.0        0.0        0.0
# 2016-09-19 01:00:00  10.0    4.0    1.0   17.0    4.0        0.0        0.0
# 2016-09-19 01:20:00  14.0   14.0    0.0   17.0    5.0        0.0        0.0
# 2016-09-19 01:40:00  10.0    7.0    2.0   11.0    4.0        0.0        0.0
# 2016-09-19 02:00:00   7.0    7.0    0.0   11.0    5.0        0.0        0.0
# 2016-09-19 02:20:00  10.0    7.0    0.0   14.0    4.0        0.0        0.0
# 2016-09-19 02:40:00   6.0   10.0    0.0   18.0    0.0        0.0        0.0
# 2016-09-19 03:00:00   9.0   10.0    0.0   10.0    5.0        0.0        0.0
# 2016-09-19 03:20:00   4.0   14.0    0.0   10.0    3.0        0.0        0.0
# ...
