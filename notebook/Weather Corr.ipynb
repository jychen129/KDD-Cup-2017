# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Handle table-like data and matrices
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import csv
import pprint

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Others
import math
from datetime import datetime, timedelta

# Configure visualisations
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 12, 8

# %%
weather_train = pd.read_csv(
    'datas/train/weather_(table_7)_training_update.csv'
)
weather_test = pd.read_csv('datas/test/weather_(table_7)_test1.csv')

weather_full = pd.concat([weather_train, weather_test]).reset_index()
weather_full.precipitation = weather_full.precipitation * 4

# %%
def get_precipitation_level(precipitation):
    if precipitation == 0.0:
        return 'Sunny'
    if precipitation < 5.0:
        return 'Light rain'
    if 5.0 <= precipitation < 10.0:
        return 'Rain'
    if 10.0 <= precipitation:
        return 'Heavy rain'

# %%
weather_full['precipitation_level'] = weather_full.precipitation.map(
    get_precipitation_level)

# %%
weather_full.precipitation_level.value_counts()
# Out:
# Sunny         797
# Light rain     78
# Heavy rain     22
# Rain           21
# Name: precipitation_level, dtype: int64

# %%
pl_dummies = pd.get_dummies(weather_full.precipitation_level)

# %%
weather_feature = weather_full[['date', 'hour']].join(pl_dummies)

# %%
def get_py_datetime(row):
    date_str = str(row[0]) + ' ' + str(row[1])
    return datetime.strptime(date_str,"%Y-%m-%d %H")

# %% [markdown]
# # 升采样并前向填充

# %%
weather_feature.index = weather_feature.apply(get_py_datetime, axis=1)
weather_feature = weather_feature.resample('20min').first()
weather_feature = weather_feature.fillna(method='ffill')
weather_feature['diff'] = abs(weather_feature.index.map(
    lambda dt: dt.hour) - weather_feature.hour)
weather_feature[weather_feature['diff']>=3] = np.nan
del weather_feature['diff']

# %%
weather_feature.to_pickle('weather_feature.pkl')

# %%
full_task2 = pd.read_pickle('task2_df.pkl').join(weather_feature)

# %%
del full_task2['hour']
del full_task2['date']

# %%
full_task2.columns = ['T1D0', 'T1D1', 'T2D0', 'T3D0', 'T3D1', 'DayOfWeek', 'Holiday',
                      'WorkingDay', 'Weekend', 'HeavyRain', 'LightRain', 'Rain', 'Sunny']

# %%
holiday_col = ['DayOfWeek', 'Holiday', 'WorkingDay', 'Weekend']
weather_col = ['HeavyRain', 'LightRain', 'Rain', 'Sunny']

# %%
full_task2[holiday_col] = full_task2[holiday_col].applymap(float)

# %%
full_task2.to_pickle('full_task2_df.pkl')

# %%
weather_feature[weather_feature == np.nan]
# Out:
#                     date  hour  Heavy rain  Light rain  Rain  Sunny
# 2016-07-01 00:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 00:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 00:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 01:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 01:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 01:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 02:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 02:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 02:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 03:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 03:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 03:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 04:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 04:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 04:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 05:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 05:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 05:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 06:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 06:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 06:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 07:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 07:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 07:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 08:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 08:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 08:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 09:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 09:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-07-01 09:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# ...                  ...   ...         ...         ...   ...    ...
# 2016-10-24 11:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 11:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 12:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 12:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 12:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 13:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 13:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 13:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 14:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 14:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 14:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 15:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 15:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 15:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 16:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 16:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 16:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 17:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 17:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 17:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 18:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 18:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 18:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 19:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 19:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 19:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 20:00:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 20:20:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 20:40:00  NaN   NaN         NaN         NaN   NaN    NaN
# 2016-10-24 21:00:00  NaN   NaN         NaN         NaN   NaN    NaN
#
# [8344 rows x 6 columns]
